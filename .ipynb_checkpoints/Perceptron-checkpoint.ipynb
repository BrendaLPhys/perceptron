# %% [markdown]
# ## Perceptron task description
#
#  "A perceptron can be used when the data is linearly separable"
#
# ![Perceptron](percept.jpg)
#
# #### Code must include:
#
# - A set of points on a 2D plane [(x1,y1), (x2,y2, ..., (xn,yn)]
# - The data separated into two categories by a line (i.e. y=2x)
# - Plot the data and the line
# - Create a perceptron function that takes the data as argument and based on the learning process finds the optimal weights that create the best line to separate the data.
# - Plot the data and the expected line and the line obtained by the perceptron in every certain amount of iterations.
# - Discuss: What is the optimal number of iterations? How many solutions can the perceptron find for this binary separation problem?

# %% [markdown]
# ### Libraries

# %%
from matplotlib import pyplot as plt
import numpy as np
np.set_printoptions(precision=2, suppress=True)

# %% [markdown]
# ### Datapoints
#
# Some linearly separable data, randomly generated:

# %%
n = 20       # any arbitrary number of datapoints

x1 = np.random.uniform(0,1,n)
x2 = np.random.uniform(0,1,n)

matrix = np.empty((n,4))

for i in range(n):
    matrix[i][0] = 1
    matrix[i][1] = x1[i]
    matrix[i][2] = x2[i]
    
    if x1[i] + x2[i] >= 1 :        # this condiction allows for linearly separable datasets
        matrix[i][3] = 1.0
    else :
        matrix[i][3] = 0.0
    
matrix
# Out:
# array([[1.  , 0.35, 0.61, 0.  ],
#        [1.  , 0.76, 0.13, 0.  ],
#        [1.  , 0.92, 0.25, 1.  ],
#        [1.  , 0.82, 0.18, 0.  ],
#        [1.  , 0.03, 0.4 , 0.  ],
#        [1.  , 0.97, 0.08, 1.  ],
#        [1.  , 0.59, 0.91, 1.  ],
#        [1.  , 0.79, 0.12, 0.  ],
#        [1.  , 0.94, 0.12, 1.  ],
#        [1.  , 0.98, 0.26, 1.  ],
#        [1.  , 0.57, 0.43, 0.  ],
#        [1.  , 0.06, 0.37, 0.  ],
#        [1.  , 0.43, 0.74, 1.  ],
#        [1.  , 0.23, 0.53, 0.  ],
#        [1.  , 0.65, 0.58, 1.  ],
#        [1.  , 0.53, 0.64, 1.  ],
#        [1.  , 0.31, 0.27, 0.  ],
#        [1.  , 0.41, 0.03, 0.  ],
#        [1.  , 0.6 , 0.35, 0.  ],
#        [1.  , 0.72, 0.06, 0.  ]])

# %% [markdown]
# ### Verify datapoint distribution is linearly separable
#
# The condition can be verified by plotting the generated datapoints

# %%
c1_data=[[],[]]
c0_data=[[],[]]

for i in range(len(matrix)):
    x1 = matrix[i][1]
    x2 = matrix[i][2]
    y  = matrix[i][-1]
    if y==1:
        c1_data[0].append(x1)
        c1_data[1].append(x2)
    else:
        c0_data[0].append(x1)
        c0_data[1].append(x2)

c0s = plt.scatter(c0_data[0],c0_data[1],s=40.0,c='r')
c1s = plt.scatter(c1_data[0],c1_data[1],s=40.0,c='b')

plt.show()

# %% [markdown]
# ### Activation function

# %%
'''This takes the place of an activation function if value is over 0 points are one class and if equals or under 0 
another class. Note to self: += adds another value with the variable's value and assigns the new value to the variable.
Note to self: The zip() function returns a zip object, which is an iterator of tuples where the first item in 
each passed iterator is paired together, and then the second item in each passed iterator are paired together etc. 
Here it is used for the inner product of two vectors.'''

def activate(inputs, weights):
    activation=0.0
    for i,w in zip(inputs,weights):
        activation += i*w 
    return 1.0 if activation>=0.0 else 0.0

# %% [markdown]
# ### Accuracy function (how close are we?)

# %%
def accuracy(matrix,weights):
    num_correct = 0.0
    predictions       = []
    for i in range(len(matrix)):
        classif   = activate(matrix[i][:-1],weights) # get predicted classification
        predictions.append(classif)
        if classif==matrix[i][-1]: num_correct+=1.0 
    #print("Predictions:",predictions)
    return num_correct/float(len(matrix))

# %% [markdown]
# ### Plotting function

# %%
def plot(matrix, title):

    fig,ax = plt.subplots()
    ax.set_title(title)
    ax.set_xlabel("x1")
    ax.set_ylabel("x2")

    axis_min=0.0
    axis_max=1.1
    y_res=0.001
    x_res=0.001
    ys=np.arange(axis_min,axis_max,y_res)
    xs=np.arange(axis_min,axis_max,x_res)
    zs=[]
    for cur_y in np.arange(axis_min,axis_max,y_res):
        for cur_x in np.arange(axis_min,axis_max,x_res):
            zs.append(activate([1.0,cur_x,cur_y],weights))
    xs,ys=np.meshgrid(xs,ys)
    zs=np.array(zs)
    zs = zs.reshape(xs.shape)
    cp=plt.contourf(xs,ys,zs,levels=[-1,-0.0001,0,1],colors=('b','r'),alpha=0.1)

    c1_data=[[],[]]
    c0_data=[[],[]]
    for i in range(len(matrix)):
        cur_x1 = matrix[i][1]
        cur_x2 = matrix[i][2]
        cur_y  = matrix[i][-1]
        if cur_y==1:
            c1_data[0].append(cur_x1)
            c1_data[1].append(cur_x2)
        else:
            c0_data[0].append(cur_x1)
            c0_data[1].append(cur_x2)

    plt.xticks(np.arange(0.0,1.1,0.1))
    plt.yticks(np.arange(0.0,1.1,0.1))
    plt.xlim(0,1.05)
    plt.ylim(0,1.05)

    c0s = plt.scatter(c0_data[0],c0_data[1],s=40.0,c='r',label='Class -1')
    c1s = plt.scatter(c1_data[0],c1_data[1],s=40.0,c='b',label='Class 1')

    plt.show()

# %% [markdown]
# ### Setting up parameters

# %%
rate = 1.2                # an optimized learning rate provided by the author of the original code
plotting = True             #set to true to plot every iteration, false to plot only the final correct line
weights = [0.2,  1.00,  -1.00] # initial weights, provided by the author of the original code

# %% [markdown]
# ### Training and best fit function

# %%
def perceptron(matrix, weights = weights, rate = rate, plotting = plotting):   
    
    accuracies = []
    iterations = []
    errors = []
    
    iteration = 0
    
    cur_acc = accuracy(matrix, weights)
    
    while cur_acc < 1.0:
        
        cur_acc = accuracy(matrix, weights)
        print("\n Iteration %d \nWeights: "%iteration, weights)
        print("Accuracy: ", cur_acc)

        if cur_acc==1.0: break 

        if plotting: plot(matrix, title="Iteration %d"%iteration)
        
        error2 = 0
        
        for i in range(len(matrix)):
            prediction = activate(matrix[i][:-1],weights) # get predicted classificaion
            error      = matrix[i][-1]-prediction         # get error from real classification          
            error2 += error**2
            for j in range(len(weights)):                 # calculate new weight for each node
                weights[j] = weights[j]+(rate*error*matrix[i][j]) 
                             
        errors.append(error2)
        
        iteration = iteration + 1   
    
        accuracies.append(cur_acc)
        iterations.append(iteration)
             
    plot(matrix, title="Final iteration")
  
    
    print('Final weights: ', weights) 
    
    iteration = iteration + 1   
    errors.append(error2)
    accuracies.append(cur_acc)
    iterations.append(iteration)
    
    fig1 = plt.figure()
    plt.plot(iterations, accuracies, marker='o', linestyle='dashed')
    fig1.suptitle('Accuracy evolution', fontsize=12)
    plt.xlabel('Iteration', fontsize=11)
    plt.ylabel('Accuracy', fontsize=11)
    
    fig2 = plt.figure()
    plt.plot(iterations, errors, marker='o', linestyle='dashed')
    fig2.suptitle('Square Error evolution', fontsize=12)
    plt.xlabel('Iteration', fontsize=11)
    plt.ylabel('SE', fontsize=11)

# %% [markdown]
# ### Test
#
# We proceed to test the perceptron function

# %%
perceptron(matrix)
# Out:
#  Iteration 0
# Weights:  [0.2, 1.0, -1.0]
# Accuracy:  0.5
#  Iteration 1
# Weights:  [-2.2, 0.6661812664527729, -0.944850267402278]
# Accuracy:  0.6
#  Iteration 2
# Weights:  [-2.2, 0.8405667419674401, 0.14218076502578814]
# Accuracy:  0.6
#  Iteration 3
# Weights:  [-2.2, 1.4307606506243793, 0.2846617388627761]
# Accuracy:  0.6
#  Iteration 4
# Weights:  [-2.2, 2.879407999622862, 0.5733045290099306]
# Accuracy:  0.75
#  Iteration 5
# Weights:  [-3.4000000000000004, 2.9611342282910966, 0.4255382544983738]
# Accuracy:  0.6
#  Iteration 6
# Weights:  [-3.4000000000000004, 3.551328136948035, 0.5680192283353618]
# Accuracy:  0.75
#  Iteration 7
# Weights:  [-3.4000000000000004, 3.5503753409119287, 1.6287038543049228]
# Accuracy:  0.85
#  Iteration 8
# Weights:  [-3.4000000000000004, 3.705542185704809, 2.2299230926164055]
# Accuracy:  0.85
#  Iteration 9
# Weights:  [-3.4000000000000004, 4.143891901269518, 2.348481424507161]
# Accuracy:  0.85
#  Iteration 10
# Weights:  [-4.6000000000000005, 3.817094771128639, 2.3314938890020125]
# Accuracy:  0.6
#  Iteration 11
# Weights:  [-4.6000000000000005, 4.407288679785578, 2.4739748628390004]
# Accuracy:  0.75
#  Iteration 12
# Weights:  [-4.6000000000000005, 4.424549382403249, 2.8988699542668694]
# Accuracy:  0.75
#  Iteration 13
# Weights:  [-4.6000000000000005, 4.44181008502092, 3.3237650456947385]
# Accuracy:  0.8
#  Iteration 14
# Weights:  [-4.6000000000000005, 4.459070787638591, 3.7486601371226076]
# Accuracy:  1.0
# Final weights:  [-4.6000000000000005, 4.459070787638591, 3.7486601371226076]
